# %% [markdown]
# # <p style="background-color:lime; font-family:calibri; color:maroon; font-size:150%; text-align:center; border-radius:15px 50px;">Data Preprocessing</p>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #C02929; font-size:115%; text-align:left">
#
# <h3 align="left"><font color=black>Objectives:
#
#
# 1. Install Libraries
# 2. Import Libraries
# 3. Load Dataset
# 4. Data Exploration
# 5. Data Quality
#    - Penanganan Nilai yang hilang
#    - Penanganan Format yang sesuai standard
# 6. Data Visualization
#
#
# </font></h3>

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 1 | Install Libraries</p>

# %%
# !pip install pandas
# !pip install numpy
# !pip install scikit-learn
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 2 | Import Libraries</p>

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 3 | Load Dataset</p>

# %%
df = pd.read_csv('datakelulusanmahasiswa.csv')

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #C02929; font-size:110%; text-align:left">
#
# <h2 align="left"><font color=black>Dataset Description:</font></h2>
#
# | __Variable__         | __Description__                                                       |
# |:---------------------|:----------------------------------------------------------------------|
# | __NAMA__             | Nama Mahasiswa                                                        |
# | __JENIS KELAMIN__    | Jenis Kelamin Mahasiswa yang terdiri dari 'Laki-Laki' dan 'Perempuan' |
# | __STATUS MAHASISWA__ | Status Mahasiswa yang terdiri dari 'Bekerja' dan 'Mahasiswa'          |
# | __UMUR__             | Usia Mahasiswa                                                        |
# | __STATUS NIKAH__     | Status Nikah terdiri dari 'Belum Menikah' dan 'Menikah'               |
# | __IPS 1__            | Indeks Prestasi Mahasiswa Semester 1                                  |
# | __IPS 2__            | Indeks Prestasi Mahasiswa Semester 2                                  |
# | __IPS 3__            | Indeks Prestasi Mahasiswa Semester 3                                  |
# | __IPS 4__            | Indeks Prestasi Mahasiswa Semester 4                                  |
# | __IPS 5__            | Indeks Prestasi Mahasiswa Semester 5                                  |
# | __IPS 6__            | Indeks Prestasi Mahasiswa Semester 6                                  |
# | __IPS 7__            | Indeks Prestasi Mahasiswa Semester 7                                  |
# | __IPS 8__            | Indeks Prestasi Mahasiswa Semester 8                                  |
# | __IPK__              | Indeks Prestasi Kumulatif Mahasiswa selama 8 semester                 |
# | __STATUS KELULUSAN__ | Status Kelulusan Mahasiswa yang terdiri dari 'Lulus' dan 'Tidak Lulus' |

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 4 | Data Exploration</p>

# %%
# Menampilkan semua baris dan kolom
df
# Out:
#                        NAMA JENIS KELAMIN STATUS MAHASISWA  UMUR  \
# 0            ANIK WIDAYANTI     pEreMpuAn          BEKERJA  28.0
# 1   DWI HESTYNA PRIHASTANTY     PEREMPUAN        MAHASISWA  32.0
# 2        MURYA ARIEF BASUKI     PEREMPUAN          BEKERJA  29.0
# 3             NANIK SUSANTI     PEREMPUAN        MAHASISWA  27.0
# 4         RIFKA ISTIQFARINA     PEREMPUAN          BEKERJA  29.0
# ..                      ...           ...              ...   ...
# 94             REZA PAHLEVI   LAKI - LAKI          BEKERJA   NaN
# 95             RINA WARDANI     PEREMPUAN          BEKERJA  27.0
# 96  ROFIDA RONING MAHANONDA     PEREMPUAN          BEKERJA  26.0
# 97       RUDIYANTI SETIASIH     PEREMPUAN        MAHASISWA  26.0
# 98        SHOFIA NUR JAMILA     PEREMPUAN        MAHASISWA  29.0
#
#      STATUS NIKAH  IPS 1  IPS 2  IPS 3  IPS 4  IPS 5  IPS 6  IPS 7  IPS 8  \
# 0   BELUM MENIKAH   2.76   2.80   3.20   3.17   2.98   3.00   3.03   0.00
# 1   BELUM MENIKAH   3.00    NaN   3.14   3.14    NaN   3.13   3.25   0.00
# 2   BELUM MENIKAH   3.50   3.30   3.70   3.29   3.53    NaN   3.73   0.00
# 3   BELUM MENIKAH   3.17   3.41   3.61   3.36   3.48   3.63   3.46   0.00
# 4   BELUM MENIKAH   2.90   2.89   3.30    NaN   2.98   3.00   3.08   0.00
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 94  BELUM MENIKAH   2.24   3.14   1.90   1.89   1.63   2.39   1.75   1.45
# 95  BELUM MENIKAH   2.74   2.41   2.75    NaN   1.68   3.13   2.52   0.88
# 96  BELUM MENIKAH   2.31   2.77    NaN   2.82   2.75   3.06   2.97   3.50
# 97  BELUM MENIKAH   2.62   3.02   2.52   2.91   2.55   2.81   2.36   0.00
# 98        MENIKAH   2.67   2.89   2.66   2.45   2.05   2.66   1.67   1.20
#
#     IPK  STATUS KELULUSAN
# 0   3.07        TERLAMBAT
# 1   3.17        TERLAMBAT
# 2   3.54        TERLAMBAT
# 3   3.41        TERLAMBAT
# 4   3.09        TERLAMBAT
# ..   ...              ...
# 94   NaN        TERLAMBAT
# 95  2.81        TERLAMBAT
# 96  2.71        TERLAMBAT
# 97  2.83        TERLAMBAT
# 98  2.53        TERLAMBAT
#
# [99 rows x 15 columns]

# %%
# Menampilkan baris pertama
df.head()
# Out:
#                       NAMA JENIS KELAMIN STATUS MAHASISWA  UMUR  \
# 0           ANIK WIDAYANTI     pEreMpuAn          BEKERJA  28.0
# 1  DWI HESTYNA PRIHASTANTY     PEREMPUAN        MAHASISWA  32.0
# 2       MURYA ARIEF BASUKI     PEREMPUAN          BEKERJA  29.0
# 3            NANIK SUSANTI     PEREMPUAN        MAHASISWA  27.0
# 4        RIFKA ISTIQFARINA     PEREMPUAN          BEKERJA  29.0
#
#     STATUS NIKAH  IPS 1  IPS 2  IPS 3  IPS 4  IPS 5  IPS 6  IPS 7  IPS 8  \
# 0  BELUM MENIKAH   2.76   2.80   3.20   3.17   2.98   3.00   3.03    0.0
# 1  BELUM MENIKAH   3.00    NaN   3.14   3.14    NaN   3.13   3.25    0.0
# 2  BELUM MENIKAH   3.50   3.30   3.70   3.29   3.53    NaN   3.73    0.0
# 3  BELUM MENIKAH   3.17   3.41   3.61   3.36   3.48   3.63   3.46    0.0
# 4  BELUM MENIKAH   2.90   2.89   3.30    NaN   2.98   3.00   3.08    0.0
#
#    IPK  STATUS KELULUSAN
# 0  3.07        TERLAMBAT
# 1  3.17        TERLAMBAT
# 2  3.54        TERLAMBAT
# 3  3.41        TERLAMBAT
# 4  3.09        TERLAMBAT

# %%
# Menampilkan baris terakhir
df.tail()
# Out:
#                        NAMA JENIS KELAMIN STATUS MAHASISWA  UMUR  \
# 94             REZA PAHLEVI   LAKI - LAKI          BEKERJA   NaN
# 95             RINA WARDANI     PEREMPUAN          BEKERJA  27.0
# 96  ROFIDA RONING MAHANONDA     PEREMPUAN          BEKERJA  26.0
# 97       RUDIYANTI SETIASIH     PEREMPUAN        MAHASISWA  26.0
# 98        SHOFIA NUR JAMILA     PEREMPUAN        MAHASISWA  29.0
#
#      STATUS NIKAH  IPS 1  IPS 2  IPS 3  IPS 4  IPS 5  IPS 6  IPS 7  IPS 8  \
# 94  BELUM MENIKAH   2.24   3.14   1.90   1.89   1.63   2.39   1.75   1.45
# 95  BELUM MENIKAH   2.74   2.41   2.75    NaN   1.68   3.13   2.52   0.88
# 96  BELUM MENIKAH   2.31   2.77    NaN   2.82   2.75   3.06   2.97   3.50
# 97  BELUM MENIKAH   2.62   3.02   2.52   2.91   2.55   2.81   2.36   0.00
# 98        MENIKAH   2.67   2.89   2.66   2.45   2.05   2.66   1.67   1.20
#
#     IPK  STATUS KELULUSAN
# 94   NaN        TERLAMBAT
# 95  2.81        TERLAMBAT
# 96  2.71        TERLAMBAT
# 97  2.83        TERLAMBAT
# 98  2.53        TERLAMBAT

# %%
# Menampilkan ringkasan dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NAMA              99 non-null     object
#  1   JENIS KELAMIN     99 non-null     object
#  2   STATUS MAHASISWA  99 non-null     object
#  3   UMUR              81 non-null     float64
#  4   STATUS NIKAH      99 non-null     object
#  5   IPS 1             96 non-null     float64
#  6   IPS 2             97 non-null     float64
#  7   IPS 3             92 non-null     float64
#  8   IPS 4             95 non-null     float64
#  9   IPS 5             93 non-null     float64
#  10  IPS 6             98 non-null     float64
#  11  IPS 7             98 non-null     float64
#  12  IPS 8             98 non-null     float64
#  13  IPK               97 non-null     float64
#  14  STATUS KELULUSAN  99 non-null     object
# dtypes: float64(10), object(5)
# memory usage: 11.7+ KB

# %%
# Menampilkan ringkasan statistik deskriptif
df.describe()
# Out:
#             UMUR      IPS 1      IPS 2      IPS 3      IPS 4      IPS 5  \
# count  81.000000  96.000000  97.000000  92.000000  95.000000  93.000000
# mean   27.839506   2.698750   2.880206   2.679674   2.624842   2.565699
# std     3.183774   0.414902   0.547386   0.555932   0.677429   0.710773
# min    25.000000   0.330000   1.090000   0.320000   0.000000   0.200000
# 25%    26.000000   2.520000   2.590000   2.320000   2.270000   2.050000
# 50%    27.000000   2.710000   2.920000   2.710000   2.750000   2.690000
# 75%    29.000000   2.912500   3.270000   3.030000   3.085000   3.150000
# max    50.000000   3.600000   3.830000   3.700000   3.890000   3.690000
#
#            IPS 6      IPS 7      IPS 8       IPK
# count  98.000000  98.000000  98.000000  97.000000
# mean    2.926020   2.744388   1.401939   2.906186
# std     0.559714   0.751535   1.287863   0.408492
# min     0.000000   0.620000   0.000000   1.390000
# 25%     2.652500   2.360000   0.000000   2.710000
# 50%     3.000000   3.015000   1.315000   3.000000
# 75%     3.267500   3.257500   2.500000   3.160000
# max     3.870000   3.810000   4.000000   3.630000

# %%
# Menampilkan spesifik kolom/atribut 'NAMA', 'JENIS KELAMIN', 'STATUS MAHASISWA', 'STATUS NIKAH', 'STATUS KELULUSAN'
df[['NAMA', 'JENIS KELAMIN', 'STATUS MAHASISWA', 'STATUS NIKAH', 'STATUS KELULUSAN']].describe()
# Out:
#                   NAMA JENIS KELAMIN STATUS MAHASISWA   STATUS NIKAH  \
# count               99            99               99             99
# unique              99             5                2              2
# top     ANIK WIDAYANTI   LAKI - LAKI          BEKERJA  BELUM MENIKAH
# freq                 1            55               64             92
#
#        STATUS KELULUSAN
# count                99
# unique                2
# top           TERLAMBAT
# freq                 81

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 5 | Data Quality</p>

# %%
# Mengecek nilai yang hilang
df.isnull().sum()
# Out:
# NAMA                 0
# JENIS KELAMIN        0
# STATUS MAHASISWA     0
# UMUR                18
# STATUS NIKAH         0
# IPS 1                3
# IPS 2                2
# IPS 3                7
# IPS 4                4
# IPS 5                6
# IPS 6                1
# IPS 7                1
# IPS 8                1
# IPK                  2
# STATUS KELULUSAN     0
# dtype: int64

# %%
# Mengisi nilai yang hilang
df['UMUR'].fillna(df['UMUR'].median(), inplace=True)
df['IPS 1'].fillna(df['IPS 1'].mean(), inplace=True)
df['IPS 2'].fillna(df['IPS 2'].mean(), inplace=True)
df['IPS 3'].fillna(df['IPS 3'].mean(), inplace=True)
df['IPS 4'].fillna(df['IPS 4'].mean(), inplace=True)
df['IPS 5'].fillna(df['IPS 5'].mean(), inplace=True)
df['IPS 6'].fillna(df['IPS 6'].mode()[0], inplace=True)
df['IPS 7'].fillna(df['IPS 7'].mode()[0], inplace=True)
df['IPS 8'].fillna(df['IPS 8'].mode()[0], inplace=True)
df['IPK '].fillna(df['IPK '].mean(), inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7036\2022804596.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['UMUR'].fillna(df['UMUR'].median(), inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_7036\2022804596.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['IPS 1'].fillna(df['IPS 1'].mean(), inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_7036\2022804596.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['IPS 2'].fillna(df['IPS 2'].mean(), inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_7036\2022804596.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['IPS 3'].fillna(df['IPS 3'].mean(), inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_7036\2022804596.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['IPS 4'].fillna(df['IPS 4'].mean(), inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_7036\2022804596.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['IPS 5'].fillna(df['IPS 5'].mean(), inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_7036\2022804596.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['IPS 6'].fillna(df['IPS 6'].mode()[0], inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_7036\2022804596.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['IPS 7'].fillna(df['IPS 7'].mode()[0], inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_7036\2022804596.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['IPS 8'].fillna(df['IPS 8'].mode()[0], inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_7036\2022804596.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['IPK '].fillna(df['IPK '].mean(), inplace=True)

# %%
print('Data setelah dibersihkan : ')
df.isnull().sum()
# Out:
# Data setelah dibersihkan :
# NAMA                0
# JENIS KELAMIN       0
# STATUS MAHASISWA    0
# UMUR                0
# STATUS NIKAH        0
# IPS 1               0
# IPS 2               0
# IPS 3               0
# IPS 4               0
# IPS 5               0
# IPS 6               0
# IPS 7               0
# IPS 8               0
# IPK                 0
# STATUS KELULUSAN    0
# dtype: int64

# %%
# Mengecek Data Duplikat
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #C02929; font-size:110%; text-align:left">
#
# <h2 align="left"><font color=black>Keterangan:</font></h2>
#
#
# * __`UMUR`__: Nilai yang hilang dari atribut Umur diisi oleh nilai median.
# * __`IPS 1`__, __`IPS 2`__, __`IPS 3`__, __`IPS 4`__, __`IPS 5`__,  __`IPK`__: Nilai yang hilang dari atribut IPS 1 hingga IPS 5 dan IPK diganti dengan nilai Mean
# * __`IPS 6`__, __`IPS 7`__, __`IPS 8`__: Nilai yang hilang dari atribut IPS 6 hingga IPS 7 diganti dengan nilai Modus

# %%
# Mengubah Value pada kolom JENIS KELAMIN

df['JENIS KELAMIN'].unique()
# Out:
# array(['pEreMpuAn', 'PEREMPUAN', 'LaKi-lAki', 'LAKI - LAKI', 'LaKi-LakI'],
#       dtype=object)

# %%
# Mengubah format standard

df['JENIS KELAMIN'] = df['JENIS KELAMIN'].replace('pEreMpuAn', 'PEREMPUAN')

# %%
df['JENIS KELAMIN'] = df['JENIS KELAMIN'].replace('LaKi-lAki', 'LAKI - LAKI')

# %%
df['JENIS KELAMIN'] = df['JENIS KELAMIN'].replace('LaKi-LakI', 'LAKI - LAKI')

# %%
df['JENIS KELAMIN'].unique()
# Out:
# array(['PEREMPUAN', 'LAKI - LAKI'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NAMA              99 non-null     object
#  1   JENIS KELAMIN     99 non-null     object
#  2   STATUS MAHASISWA  99 non-null     object
#  3   UMUR              99 non-null     float64
#  4   STATUS NIKAH      99 non-null     object
#  5   IPS 1             99 non-null     float64
#  6   IPS 2             99 non-null     float64
#  7   IPS 3             99 non-null     float64
#  8   IPS 4             99 non-null     float64
#  9   IPS 5             99 non-null     float64
#  10  IPS 6             99 non-null     float64
#  11  IPS 7             99 non-null     float64
#  12  IPS 8             99 non-null     float64
#  13  IPK               99 non-null     float64
#  14  STATUS KELULUSAN  99 non-null     object
# dtypes: float64(10), object(5)
# memory usage: 11.7+ KB

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #C02929; font-size:110%; text-align:left">
#
# <h2 align="left"><font color=black>Keterangan:</font></h2>
#
#
# * __`JENIS KELAMIN`__: Nilai yang formatnya tidak sesuai diubah menjadi format yang sesuai menjadi 'LAKI - LAKI' dan 'PEREMPUAN'

# %%
# Encode categorical variables
le = preprocessing.LabelEncoder()
df['JENIS KELAMIN'] = le.fit_transform(df['JENIS KELAMIN'])

# %%
df['STATUS MAHASISWA'] = le.fit_transform(df['STATUS MAHASISWA'])

# %%
df['STATUS NIKAH'] = le.fit_transform(df['STATUS NIKAH'])

# %%
df['STATUS KELULUSAN'] = le.fit_transform(df['STATUS KELULUSAN'])

# %%
df
# Out:
#                        NAMA  JENIS KELAMIN  STATUS MAHASISWA  UMUR  \
# 0            ANIK WIDAYANTI              1                 0  28.0
# 1   DWI HESTYNA PRIHASTANTY              1                 1  32.0
# 2        MURYA ARIEF BASUKI              1                 0  29.0
# 3             NANIK SUSANTI              1                 1  27.0
# 4         RIFKA ISTIQFARINA              1                 0  29.0
# ..                      ...            ...               ...   ...
# 94             REZA PAHLEVI              0                 0  27.0
# 95             RINA WARDANI              1                 0  27.0
# 96  ROFIDA RONING MAHANONDA              1                 0  26.0
# 97       RUDIYANTI SETIASIH              1                 1  26.0
# 98        SHOFIA NUR JAMILA              1                 1  29.0
#
#     STATUS NIKAH  IPS 1     IPS 2     IPS 3     IPS 4     IPS 5  IPS 6  IPS 7  \
# 0              0   2.76  2.800000  3.200000  3.170000  2.980000   3.00   3.03
# 1              0   3.00  2.880206  3.140000  3.140000  2.565699   3.13   3.25
# 2              0   3.50  3.300000  3.700000  3.290000  3.530000   3.00   3.73
# 3              0   3.17  3.410000  3.610000  3.360000  3.480000   3.63   3.46
# 4              0   2.90  2.890000  3.300000  2.624842  2.980000   3.00   3.08
# ..           ...    ...       ...       ...       ...       ...    ...    ...
# 94             0   2.24  3.140000  1.900000  1.890000  1.630000   2.39   1.75
# 95             0   2.74  2.410000  2.750000  2.624842  1.680000   3.13   2.52
# 96             0   2.31  2.770000  2.679674  2.820000  2.750000   3.06   2.97
# 97             0   2.62  3.020000  2.520000  2.910000  2.550000   2.81   2.36
# 98             1   2.67  2.890000  2.660000  2.450000  2.050000   2.66   1.67
#
#     IPS 8      IPK   STATUS KELULUSAN
# 0    0.00  3.070000                 1
# 1    0.00  3.170000                 1
# 2    0.00  3.540000                 1
# 3    0.00  3.410000                 1
# 4    0.00  3.090000                 1
# ..    ...       ...               ...
# 94   1.45  2.906186                 1
# 95   0.88  2.810000                 1
# 96   3.50  2.710000                 1
# 97   0.00  2.830000                 1
# 98   1.20  2.530000                 1
#
# [99 rows x 15 columns]

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #C02929; font-size:110%; text-align:left">
#
# <h2 align="left"><font color=black>Keterangan:</font></h2>
#
#
# * __`JENIS KELAMIN`__: Nilai dari Atribut Jenis Kelamin diubah menjadi nilai 0 dan 1 menggunakan fungsi Label Encoder yang mana 'Laki - Laki' menjadi '0' dan 'PEREMPUAN' menjadi '1'
# * __`STATUS MAHASISWA`__: Nilai dari Atribut Status Mahasiswa diubah menjadi nilai 0 dan 1 menggunakan fungsi Label Encoder yang mana 'Bekerja' menjadi '0' dan 'Mahasiswa' menjadi '1'
# * __`STATUS NIKAH`__: Nilai dari Atribut Status Nikah diubah menjadi nilai 0 dan 1 menggunakan fungsi Label Encoder yang mana 'Belum Menikah' menjadi '0' dan 'Menikah' menjadi '1'
# * __`STATUS KELULUSAN`__: Nilai dari Atribut Status Kelulusan diubah menjadi nilai 0 dan 1 menggunakan fungsi Label Encoder yang mana 'Tepat' menjadi '0' dan 'Terlambat' menjadi '1'

# %%
df['IPS 1'] = df['IPS 1'].round(2)
df['IPS 2'] = df['IPS 2'].round(2)
df['IPS 3'] = df['IPS 3'].round(2)
df['IPS 4'] = df['IPS 4'].round(2)
df['IPS 5'] = df['IPS 5'].round(2)
df['IPS 6'] = df['IPS 6'].round(2)
df['IPS 7'] = df['IPS 7'].round(2)
df['IPS 8'] = df['IPS 8'].round(2)
df['IPK '] = df['IPK '].round(2)

# %%
df
# Out:
#                        NAMA  JENIS KELAMIN  STATUS MAHASISWA  UMUR  \
# 0            ANIK WIDAYANTI              1                 0  28.0
# 1   DWI HESTYNA PRIHASTANTY              1                 1  32.0
# 2        MURYA ARIEF BASUKI              1                 0  29.0
# 3             NANIK SUSANTI              1                 1  27.0
# 4         RIFKA ISTIQFARINA              1                 0  29.0
# ..                      ...            ...               ...   ...
# 94             REZA PAHLEVI              0                 0  27.0
# 95             RINA WARDANI              1                 0  27.0
# 96  ROFIDA RONING MAHANONDA              1                 0  26.0
# 97       RUDIYANTI SETIASIH              1                 1  26.0
# 98        SHOFIA NUR JAMILA              1                 1  29.0
#
#     STATUS NIKAH  IPS 1  IPS 2  IPS 3  IPS 4  IPS 5  IPS 6  IPS 7  IPS 8  \
# 0              0   2.76   2.80   3.20   3.17   2.98   3.00   3.03   0.00
# 1              0   3.00   2.88   3.14   3.14   2.57   3.13   3.25   0.00
# 2              0   3.50   3.30   3.70   3.29   3.53   3.00   3.73   0.00
# 3              0   3.17   3.41   3.61   3.36   3.48   3.63   3.46   0.00
# 4              0   2.90   2.89   3.30   2.62   2.98   3.00   3.08   0.00
# ..           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 94             0   2.24   3.14   1.90   1.89   1.63   2.39   1.75   1.45
# 95             0   2.74   2.41   2.75   2.62   1.68   3.13   2.52   0.88
# 96             0   2.31   2.77   2.68   2.82   2.75   3.06   2.97   3.50
# 97             0   2.62   3.02   2.52   2.91   2.55   2.81   2.36   0.00
# 98             1   2.67   2.89   2.66   2.45   2.05   2.66   1.67   1.20
#
#     IPK   STATUS KELULUSAN
# 0   3.07                 1
# 1   3.17                 1
# 2   3.54                 1
# 3   3.41                 1
# 4   3.09                 1
# ..   ...               ...
# 94  2.91                 1
# 95  2.81                 1
# 96  2.71                 1
# 97  2.83                 1
# 98  2.53                 1
#
# [99 rows x 15 columns]

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #C02929; font-size:110%; text-align:left">
#
# <h2 align="left"><font color=black>Keterangan:</font></h2>
#
#
# * __`IPS 1`__, __`IPS 2`__, __`IPS 3`__, __`IPS 4`__, __`IPS 5`__, __`IPS 6`__, __`IPS 7`__, __`IPS 8`__, __`IPK`__: Nilai dari IPS 1 hingga IPK dibulatkan 2 angka dibelakang koma

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 6 | Data Visualization</p>

# %%
# Menampilkan visualisasi Jenis Kelamin

df['JENIS KELAMIN'].plot(kind='hist', bins = 20, title='JENIS KELAMIN')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Menampilkan visualisasi Status Mahasiswa
df['STATUS MAHASISWA'].plot(kind='hist', bins=20, title='STATUS MAHASISWA')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['UMUR'].plot(kind='hist', bins=20, title='UMUR')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
sns.countplot(data=df, x='JENIS KELAMIN', hue='STATUS KELULUSAN')
plt.title('Jenis Kelamin vs Status Kelulusan')
plt.xlabel('Jenis Kelamin')
plt.ylabel('Jumlah')
plt.legend(title='Status Kelulusan')
plt.show()

# %%
# Menampilkan visualisasi Line Chart untuk kolom IPK
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='STATUS MAHASISWA', hue='STATUS KELULUSAN')
plt.title('Status Mahasiswa vs Status Kelulusan')
plt.xlabel('STATUS MAHASISWA')
plt.ylabel('STATUS KELULUSAN')
plt.legend(title='Status Kelulusan')
plt.xticks([0,1], ['Bekerja', 'Mahasiswa'])
plt.show()

# %%
# Menampilkan visualisasi Line Chart untuk kolom IPK
plt.figure(figsize=(10, 5))
plt.plot(df['IPK '], marker='o', linestyle='-', color='b')
plt.title('Line Chart IPK')
plt.xlabel('Index')
plt.ylabel('IPK')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))

for i in range(1, 9):
    kolom_ips = f'IPS {i}'
    plt.plot(df[kolom_ips], label=kolom_ips, marker='o', linestyle='-', markersize=4)

plt.title('Perbandingan IPS 1 sampai IPS 8')
plt.xlabel('Indeks Mahasiswa')
plt.ylabel('Nilai IPS')

# Memperbaiki penggunaan legend
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1))  # Memperbaiki parameter bbox_to_anchor
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Membuat heatmap korelasi
plt.figure(figsize=(10, 8))

IPS = ['IPS 1', 'IPS 2', 'IPS 3', 'IPS 4', 'IPS 5', 'IPS 6', 'IPS 7', 'IPS 8', 'IPK ']
correlation_matrix = df[IPS].corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5, fmt='.2f')
plt.title('Heatmap Korelasi IPS dan IPK')
plt.tight_layout()
plt.show()
